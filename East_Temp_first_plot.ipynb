# %%
import pandas as pd

import numpy as np

# %%
eas= pd.read_csv('East_temp.csv')

eas
# Out:
#             COMID  Maheu_type  hivar_cool  sta_cold  sta_cool  var_cold  \
# 0             179  hivar_cool       0.446     0.114     0.148     0.264
# 1             181  hivar_cool       0.496     0.096     0.126     0.258
# 2             183    var_cold       0.396     0.066     0.088     0.436
# 3             185    var_cold       0.396     0.066     0.088     0.436
# 4             843  hivar_cool       0.358     0.106     0.172     0.338
# 5             845  hivar_cool       0.356     0.102     0.164     0.356
# 6             847  hivar_cool       0.354     0.108     0.164     0.348
# 7             849    var_cold       0.338     0.094     0.118     0.426
# 8             851  hivar_cool       0.364     0.138     0.164     0.316
# 9             853    var_cold       0.304     0.114     0.140     0.416
# 10            855    var_cold       0.358     0.094     0.126     0.400
# 11            857    var_cold       0.346     0.094     0.120     0.418
# ...

# %%
eas.columns
# Out:
# Index(['COMID', 'Maheu_type', 'hivar_cool', 'sta_cold', 'sta_cool', 'var_cold',
#        'var_cool', 'var_warm', 'JulAug_tempC', 'JulAug_Class'],
#       dtype='object')

# %%
eas['JulAug_tempC'].values.mean()
# Out:
# 21.243442591579385

# %%
import matplotlib
import seaborn as sns
sns.set()

# %%
p = 21.243442591579385
ix = eas['JulAug_tempC'] > p
eas['JulAug_tempC'].loc[ix]
# Out:
# 134       21.598790
# 237       21.395413
# 240       21.455152
# 283       21.552240
# 285       21.550826
# 286       21.525748
# 290       21.442488
# 291       21.481747
# 310       22.000230
# 324       21.511423
# 329       21.518978
# 355       21.913111
# 357       21.903417
# 360       21.948048
# 361       21.930795
# 363       21.920189
# 364       21.947210
# 365       21.932967
# 367       21.949933
# 368       21.480468
# 370       21.970492
# 372       21.955270
# 373       21.552240
# 375       21.501795
# 376       21.526093
# 377       21.478531
# 382       21.461213
# 386       21.439763
# 389       21.481044
# 393       21.482354
#             ...
# 678531    25.442824
# 678532    25.506860
# 678533    25.607638
# 678534    25.599235
# 678535    24.424244
# 678536    24.770166
# 678537    24.522231
# 678538    24.868826
# 678539    26.465889
# 678540    26.466924
# 678541    28.267669
# 678542    28.251175
# 678545    27.798429
# 678546    27.798429
# ...

# %%
eas['JulAug_tempC'].loc[ix].hist(bins=50)
